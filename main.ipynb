# %% [markdown]
# # ACT460 Project - Team 11
#
# Path-dependent options

# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Question 1

# %%
# code for question 1

# %% [markdown]
# ### Question 2

# %%
# code for question 2

# %% [markdown]
# ### Question 3

# %%
# code for question 3

# %% [markdown]
# ### Question 4

# %%
# code for question 4

# %% [markdown]
# ### Question 5

# %%
# code for question 5

# %% [markdown]
# ### Question 6

# %%
# code for question 6
